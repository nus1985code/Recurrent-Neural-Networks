# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense
from tensorflow.keras.models import Model

# %%
# Parameters
max_words = 10000  # Only consider the top 10,000 words
max_len = 500      # Maximum review length (pad the rest)
embedding_dim = 32 # Dimensionality of word embeddings

# %%
# Load the dataset
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_words)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Pad the sequences
x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)

# %%
# Build the RNN model
model = Sequential([
    Input(shape=(max_len,)),  # Explicitly specify the input shape
    Embedding(input_dim=max_words, output_dim=embedding_dim),
    SimpleRNN(units=32),
    Dense(1, activation='sigmoid')  # Binary classification
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary to check layers
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ (None, 500, 32)             │         320,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_1 (SimpleRNN)             │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 322,113 (1.23 MB)
#  Trainable params: 322,113 (1.23 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(x_train, y_train,
                    epochs=10,
                    batch_size=128,
                    validation_split=0.2,
                    verbose=1)
# Out:
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 31s 180ms/step - accuracy: 0.5391 - loss: 0.6869 - val_accuracy: 0.6686 - val_loss: 0.6058
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 182ms/step - accuracy: 0.7669 - loss: 0.5119 - val_accuracy: 0.8212 - val_loss: 0.4214
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 30s 193ms/step - accuracy: 0.8774 - loss: 0.2995 - val_accuracy: 0.8272 - val_loss: 0.4161
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 39s 183ms/step - accuracy: 0.9425 - loss: 0.1679 - val_accuracy: 0.8394 - val_loss: 0.4149
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 43s 193ms/step - accuracy: 0.9812 - loss: 0.0762 - val_accuracy: 0.8124 - val_loss: 0.5064
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 40s 185ms/step - accuracy: 0.9951 - loss: 0.0317 - val_accuracy: 0.8276 - val_loss: 0.5277
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 184ms/step - accuracy: 0.9984 - loss: 0.0142 - val_accuracy: 0.8254 - val_loss: 0.5772
# Epoch 8/10
# ...

# %% [markdown]
# # **TO CHECK OVERFITTING**

# %%
import matplotlib.pyplot as plt

# Accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping

# Build the RNN model with Dropout and L2 Regularization
model = Sequential([
    Input(shape=(max_len,)),  # Explicitly specify the input shape
    Embedding(input_dim=max_words, output_dim=embedding_dim),

    # SimpleRNN layer with L2 Regularization
    SimpleRNN(units=16, kernel_regularizer=regularizers.l2(0.001)),

    # Dropout layer to prevent overfitting
    Dropout(0.7),

    # Output layer for binary classification
    Dense(1, activation='sigmoid')  # Binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Add EarlyStopping to monitor validation loss and stop training early if it stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model with EarlyStopping callback
history1 = model.fit(x_train, y_train,
                    epochs=10,
                    batch_size=128,
                    validation_split=0.2,
                    callbacks=[early_stopping],
                    verbose=1)
# Out:
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 28s 166ms/step - accuracy: 0.5659 - loss: 0.6993 - val_accuracy: 0.7972 - val_loss: 0.5162
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 40s 161ms/step - accuracy: 0.8036 - loss: 0.5060 - val_accuracy: 0.8060 - val_loss: 0.4659
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 162ms/step - accuracy: 0.8391 - loss: 0.4393 - val_accuracy: 0.8324 - val_loss: 0.4196
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 160ms/step - accuracy: 0.8811 - loss: 0.3540 - val_accuracy: 0.8302 - val_loss: 0.4218
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 40s 154ms/step - accuracy: 0.9052 - loss: 0.3041 - val_accuracy: 0.8358 - val_loss: 0.4140
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 42s 160ms/step - accuracy: 0.8708 - loss: 0.3426 - val_accuracy: 0.6878 - val_loss: 0.5969
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 161ms/step - accuracy: 0.8078 - loss: 0.4510 - val_accuracy: 0.8144 - val_loss: 0.4514
# Epoch 8/10
# ...

# %%
# Accuracy
plt.plot(history1.history['accuracy'], label='Training Accuracy')
plt.plot(history1.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss
plt.plot(history1.history['loss'], label='Training Loss')
plt.plot(history1.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Build the RNN model with Dropout and L2 Regularization
model = Sequential([
    Input(shape=(max_len,)),  # Explicitly specify the input shape
    Embedding(input_dim=max_words, output_dim=embedding_dim),

    # SimpleRNN layer with L2 Regularization
    SimpleRNN(units=8, kernel_regularizer=regularizers.l2(0.001)),

    # Dropout layer to prevent overfitting
    Dropout(0.6),

    # Output layer for binary classification
    Dense(1, activation='sigmoid')  # Binary classification
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Add EarlyStopping to monitor validation loss and stop training early if it stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model with EarlyStopping callback
history2 = model.fit(x_train, y_train,
                    epochs=10,
                    batch_size=128,
                    validation_split=0.2,
                    callbacks=[early_stopping],
                    verbose=1)
# Out:
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 26s 157ms/step - accuracy: 0.5460 - loss: 0.7001 - val_accuracy: 0.7924 - val_loss: 0.5041
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 24s 154ms/step - accuracy: 0.8060 - loss: 0.4920 - val_accuracy: 0.7972 - val_loss: 0.4706
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 23s 146ms/step - accuracy: 0.8213 - loss: 0.4472 - val_accuracy: 0.8362 - val_loss: 0.4116
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 42s 155ms/step - accuracy: 0.8670 - loss: 0.3637 - val_accuracy: 0.8370 - val_loss: 0.4105
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 154ms/step - accuracy: 0.8943 - loss: 0.3178 - val_accuracy: 0.7150 - val_loss: 0.5609
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - accuracy: 0.8412 - loss: 0.3970 - val_accuracy: 0.8342 - val_loss: 0.4147
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 24s 154ms/step - accuracy: 0.9081 - loss: 0.2759 - val_accuracy: 0.8360 - val_loss: 0.4125

# %%
# Accuracy
plt.plot(history2.history['accuracy'], label='Training Accuracy')
plt.plot(history2.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss
plt.plot(history2.history['loss'], label='Training Loss')
plt.plot(history2.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print(f'Test Accuracy: {test_accuracy:.4f}')
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 20s 26ms/step - accuracy: 0.8239 - loss: 0.4228
# Test Accuracy: 0.8259

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict using the trained model
y_pred = (model.predict(x_test) > 0.5).astype("int32")

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84     12500
#            1       0.87      0.76      0.81     12500
#
#     accuracy                           0.83     25000
#    macro avg       0.83      0.83      0.83     25000
# weighted avg       0.83      0.83      0.83     25000
